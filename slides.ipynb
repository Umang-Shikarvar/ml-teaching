# %% [markdown]
# # Lecture Slides
#
# ## Course Materials by Category
#
# ### Basics & Foundations
#
# Fundamental concepts and prerequisites for machine learning.
#
# -   [Introduction and Logistics](basics/slides/1-introduction-ml.pdf)
# -   [Convention, Metrics, Classification,
#     Regression](basics/slides/accuracy-convention.pdf)
# -   [Accuracy Metrics &
#     Classification](basics/slides/accuracy_convention.pdf)
# -   [Data Shuffling](basics/slides/shuffling.pdf)
# -   [Miscellaneous Topics](basics/slides/misc.pdf)
#
# ### Mathematical Foundations
#
# Core mathematical concepts underlying machine learning algorithms.
#
# -   [Mathematical Foundations](maths/slides/ml-maths.pdf)
# -   [Mathematical ML Foundations](maths/slides/mathematical-ml.pdf)
# -   [Contour Plots & Visualization](maths/slides/ml-maths-2-contour.pdf)
# -   [Multivariate Normal Distribution](maths/slides/mvn.pdf)
# -   [Multivariate Normal II](maths/slides/mvn2.pdf)
# -   [KKT Conditions](maths/slides/kkt-conditions.pdf)
# -   [Constrained Optimization I](maths/slides/constrained-1.pdf)
# -   [Constrained Optimization II](maths/slides/constrained-2.pdf)
# -   [Time Complexity](maths/slides/time_complexity.pdf)
# -   [Finding Optimal Widths](maths/slides/find-widths.pdf)
#
# ### Optimization Algorithms
#
# Techniques for finding optimal solutions in machine learning.
#
# -   [Gradient Descent](optimization/slides/gradient-descent.pdf)
# -   [Coordinate Descent](optimization/slides/coordinate_descent.pdf)
# -   [Coordinate Descent
#     (Alternative)](optimization/slides/coordinate-descent.pdf)
# -   [Coordinate Descent
#     (Minimal)](optimization/slides/coordinate-descent-minimal.pdf)
# -   [Coordinate Descent
#     Failures](optimization/slides/coordinate-descent-fail.pdf)
# -   [Coordinate Descent with
#     Rho](optimization/slides/coordinate-rho.pdf)
# -   [Coordinate Descent
#     Thresholding](optimization/slides/coordinate-thresholding.pdf)
# -   [Coordinate Descent
#     Visualization](optimization/slides/coordinate-vis.pdf)
# -   [Subgradient Methods](optimization/slides/subgradient.pdf)
# -   [Convexity](optimization/slides/convexity.pdf)
# -   [Stochastic Gradient Descent](optimization/slides/SGD.pdf)
#
# ### Supervised Learning
#
# Algorithms that learn from labeled data.
#
# -   [Decision Trees](supervised/slides/decision-trees.pdf)
# -   [Bias-Variance Tradeoff](supervised/slides/bias-variance.pdf)
# -   [Bias-Variance II](supervised/slides/bias-variance-2.pdf)
# -   [Cross-Validation](supervised/slides/cross-validation.pdf)
# -   [Ensemble Methods](supervised/slides/ensemble.pdf)
# -   [Linear Regression](supervised/slides/linear-regression.pdf)
# -   [Logistic Regression](supervised/slides/logistic-regression.pdf)
# -   [K-Nearest Neighbors](supervised/slides/knn.pdf)
# -   [KNN Approximation Methods](supervised/slides/knn-approx.pdf)
# -   [Naive Bayes](supervised/slides/naive-bayes.pdf)
# -   [Bayesian Networks](supervised/slides/bayesian-nets.pdf)
# -   [Ridge Regression](supervised/slides/ridge-regression.pdf)
# -   [Ridge Regression with
#     Cross-Validation](supervised/slides/ridge-cv.pdf)
# -   [Ridge Regression with Gradient
#     Descent](supervised/slides/ridge-gd.pdf)
# -   [Ridge Regression with
#     Intercept](supervised/slides/ridge-intercept.pdf)
# -   [Lasso Regression](supervised/slides/lasso-regression.pdf)
# -   [Lasso Solution Methods](supervised/slides/lasso-solution.pdf)
# -   [Lasso for Sparse Models](supervised/slides/lasso-sparse.pdf)
# -   [Kernel Density Estimation I](supervised/slides/kde1.pdf)
# -   [Kernel Density Estimation II](supervised/slides/kde2.pdf)
# -   [2D Kernel Density Estimation](supervised/slides/kde2d.pdf)
# -   [Movie Recommendation
#     Systems](supervised/slides/movie-recommendation.pdf)
# -   [Feature Selection](supervised/slides/feature-selection.pdf)
# -   [SVM Introduction](supervised/slides/svm-intro.pdf)
# -   [SVM Soft Margin](supervised/slides/svm-soft-margin.pdf)
# -   [SVM Kernel Methods](supervised/slides/svm-kernel.pdf)
# -   [More SVM Topics](supervised/slides/svm-2-2.pdf)
# -   [SVM Advanced Topics I](supervised/slides/svm-3.pdf)
# -   [SVM Advanced Topics II](supervised/slides/svm-4.pdf)
# -   [SVM Complete Series](supervised/slides/Svm1&2.pdf)
# -   [Logistic Regression
#     Hessian](supervised/slides/Logistic-Hessian.pdf)
# -   [Weighted Least Squares](supervised/slides/Weighted-least.pdf)
# -   [Violin Plots Visualization](supervised/slides/violin.pdf)
#
# ### Neural Networks & Deep Learning
#
# Modern neural network architectures and deep learning techniques.
#
# -   [Multi-Layer Perceptrons](neural-networks/slides/mlp.pdf)
# -   [Next Token Generation](neural-networks/slides/next.pdf)
# -   [Next Token
#     Prediction](neural-networks/slides/next-token-prediction.pdf)
# -   [Convolutional Neural Networks](neural-networks/slides/cnn.pdf)
# -   [1D CNNs](neural-networks/slides/cnn-1d.pdf)
# -   [Automatic Differentiation](neural-networks/slides/autograd.pdf)
#
# ### Advanced Topics
#
# Specialized techniques and cutting-edge approaches.
#
# -   [Time Series Forecasting](advanced/slides/forecasting.pdf)
# -   [Reinforcement Learning](advanced/slides/rl.pdf)
#
# ### Unsupervised Learning
#
# Algorithms that find patterns in unlabeled data.
#
# -   [Clustering & Dimensionality
#     Reduction](unsupervised/slides/unsupervised.pdf)
#
# ------------------------------------------------------------------------
#
# ## How to Use These Materials
#
# -   **For Students**: Navigate through topics sequentially, starting
#     with Basics & Foundations
# -   **For Instructors**: Each category is self-contained and can be
#     taught independently
# -   **PDF Quality**: All slides are optimized for both viewing and
#     printing
#
# ## Quick Links
#
# -   [Interactive Notebooks](notebooks.qmd) - Hands-on coding examples
# -   [Course Homepage](index.qmd) - Return to main page
# -   [Instructor](https://nipunbatra.github.io) - Nipun Batra’s homepage
